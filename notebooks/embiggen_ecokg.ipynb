# %%
# !pip install ensmallen
# !pip install embiggen
# !pip install tensorflow
# Out:
# Requirement already satisfied: ensmallen in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (0.6.6)
# Requirement already satisfied: tqdm in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (4.62.3)
# Requirement already satisfied: pandas in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (1.3.4)
# Requirement already satisfied: toml~=0.10.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (0.10.2)
# Requirement already satisfied: compress_json in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (1.0.4)
# Requirement already satisfied: environments_utils in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (1.0.3)
# Requirement already satisfied: py-cpuinfo in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (8.0.0)
# Requirement already satisfied: userinput in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (1.0.15)
# Requirement already satisfied: downloaders in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen) (1.0.12)
# Requirement already satisfied: pytz>=2017.3 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from pandas->ensmallen) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from pandas->ensmallen) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from pandas->ensmallen) (1.21.3)
# Requirement already satisfied: six>=1.5 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->ensmallen) (1.16.0)
# Requirement already satisfied: validators in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen) (0.18.2)
# Requirement already satisfied: IPy in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen) (1.1)
# Requirement already satisfied: validate-email in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen) (1.3)
# Requirement already satisfied: validate-version-code in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen) (1.0.4)
# Requirement already satisfied: ipython in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen) (7.28.0)
# Requirement already satisfied: decorator in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (58.1.0)
# Requirement already satisfied: backcall in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (3.0.21)
# Requirement already satisfied: appnope in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (0.1.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (5.1.0)
# Requirement already satisfied: pexpect>4.3 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (0.1.3)
# Requirement already satisfied: pickleshare in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (0.7.5)
# Requirement already satisfied: pygments in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen) (2.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython->userinput->ensmallen) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython->userinput->ensmallen) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->userinput->ensmallen) (0.2.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: embiggen in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (0.9.3)
# Requirement already satisfied: tqdm in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (4.62.3)
# Requirement already satisfied: matplotlib in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (3.4.3)
# Requirement already satisfied: sklearn in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (0.0)
# Requirement already satisfied: keras-mixed-sequence>=1.0.27 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (1.0.27)
# Requirement already satisfied: validate-version-code in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (1.0.4)
# Requirement already satisfied: ensmallen>=0.6.2 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (0.6.6)
# Requirement already satisfied: pandas in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (1.3.4)
# Requirement already satisfied: sanitize-ml-labels>=1.0.26 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (1.0.26)
# Requirement already satisfied: numpy in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (1.21.3)
# Requirement already satisfied: ddd-subplots>=1.0.7 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (1.0.9)
# Requirement already satisfied: packaging in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (21.0)
# Requirement already satisfied: extra-keras-metrics>=2.0.2 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (2.0.2)
# Requirement already satisfied: cache-decorator>=2.0.2 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from embiggen) (2.0.9)
# Requirement already satisfied: compress-json>=1.0.4 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from cache-decorator>=2.0.2->embiggen) (1.0.4)
# Requirement already satisfied: compress-pickle>=2.0.1 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from cache-decorator>=2.0.2->embiggen) (2.1.0)
# Requirement already satisfied: deflate-dict in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from cache-decorator>=2.0.2->embiggen) (1.0.9)
# Requirement already satisfied: dict-hash>=1.1.17 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from cache-decorator>=2.0.2->embiggen) (1.1.19)
# Requirement already satisfied: humanize>=3.4.1 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from cache-decorator>=2.0.2->embiggen) (3.12.0)
# Requirement already satisfied: pygifsicle in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ddd-subplots>=1.0.7->embiggen) (1.0.5)
# Requirement already satisfied: imageio in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ddd-subplots>=1.0.7->embiggen) (2.9.0)
# Requirement already satisfied: environments_utils in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen>=0.6.2->embiggen) (1.0.3)
# Requirement already satisfied: userinput in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen>=0.6.2->embiggen) (1.0.15)
# Requirement already satisfied: downloaders in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen>=0.6.2->embiggen) (1.0.12)
# Requirement already satisfied: py-cpuinfo in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen>=0.6.2->embiggen) (8.0.0)
# Requirement already satisfied: toml~=0.10.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ensmallen>=0.6.2->embiggen) (0.10.2)
# Requirement already satisfied: decorator in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from extra-keras-metrics>=2.0.2->embiggen) (5.1.0)
# Requirement already satisfied: setuptools in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from humanize>=3.4.1->cache-decorator>=2.0.2->embiggen) (58.1.0)
# Requirement already satisfied: pillow in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from imageio->ddd-subplots>=1.0.7->embiggen) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from matplotlib->embiggen) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from matplotlib->embiggen) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from matplotlib->embiggen) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from matplotlib->embiggen) (2.8.2)
# Requirement already satisfied: six in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->embiggen) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from pandas->embiggen) (2021.3)
# Requirement already satisfied: scikit-learn in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from sklearn->embiggen) (1.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from scikit-learn->sklearn->embiggen) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from scikit-learn->sklearn->embiggen) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from scikit-learn->sklearn->embiggen) (3.0.0)
# Requirement already satisfied: validators in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen>=0.6.2->embiggen) (0.18.2)
# Requirement already satisfied: validate-email in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen>=0.6.2->embiggen) (1.3)
# Requirement already satisfied: IPy in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen>=0.6.2->embiggen) (1.1)
# Requirement already satisfied: ipython in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from userinput->ensmallen>=0.6.2->embiggen) (7.28.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (5.1.0)
# Requirement already satisfied: matplotlib-inline in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (0.1.3)
# Requirement already satisfied: appnope in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (0.1.2)
# Requirement already satisfied: pygments in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (2.10.0)
# Requirement already satisfied: pexpect>4.3 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (4.8.0)
# Requirement already satisfied: backcall in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (3.0.21)
# Requirement already satisfied: pickleshare in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from ipython->userinput->ensmallen>=0.6.2->embiggen) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython->userinput->ensmallen>=0.6.2->embiggen) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython->userinput->ensmallen>=0.6.2->embiggen) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->userinput->ensmallen>=0.6.2->embiggen) (0.2.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/bin/python -m pip install --upgrade pip' command.
# Collecting tensorflow
#   Downloading tensorflow-2.6.0-cp39-cp39-macosx_10_11_x86_64.whl (199.0 MB)
#      |████████████████████████████████| 199.0 MB 52 kB/s
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp39-cp39-macosx_10_9_x86_64.whl (2.9 MB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.0-cp39-cp39-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 11.5 MB/s
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-estimator~=2.6
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 11.1 MB/s
# Collecting six~=1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 11.0 MB/s
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting keras~=2.6
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 11.3 MB/s
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1-cp39-cp39-macosx_10_15_x86_64.whl
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: wheel~=0.35 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from tensorflow) (0.37.0)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp39-cp39-macosx_10_9_x86_64.whl (15.6 MB)
# Collecting grpcio<2.0,>=1.37.0
#   Using cached grpcio-1.41.0-cp39-cp39-macosx_10_10_x86_64.whl (3.9 MB)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 12.3 MB/s
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (58.1.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.3.0-py2.py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 11.3 MB/s
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 11.0 MB/s
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.7)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Building wheels for collected packages: clang
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30692 sha256=525a33aeac4d452a52494c545de03f980a0cba5d42995726ca9b643c08888af0
#   Stored in directory: /Users/faisala/Library/Caches/pip/wheels/3a/ce/7a/27094f689461801c934296d07078773603663dfcaca63bb064
# Successfully built clang
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, six, requests-oauthlib, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, numpy, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, typing-extensions, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.3
#     Uninstalling numpy-1.21.3:
#       Successfully uninstalled numpy-1.21.3
# Successfully installed absl-py-0.15.0 astunparse-1.6.3 cachetools-4.2.4 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.3.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.41.0 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.4 numpy-1.19.5 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.19.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7.2 six-1.15.0 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.6.0 tensorflow-estimator-2.6.0 termcolor-1.1.0 typing-extensions-3.7.4.3 werkzeug-2.0.2 wrapt-1.12.1
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/faisala/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/bin/python -m pip install --upgrade pip' command.

# %%
from ensmallen import Graph

g = Graph.from_csv(
    # node_type_path="data/merged-kg_nodes.tsv",
    # nodes_column="id",
    # node_list_header=True,
    # node_list_separator="\t",

    edge_path="data/merged-kg_edges.tsv",
    sources_column="subject",
    destinations_column="object",
    edge_list_header=True,
    edge_list_separator="\t",

    directed=False, # FIXME: it's directed, but compute_node_embedding() (below) isn't compatible with directed graphs...?

    # probably some other arguments too, see here:
    # https://github.com/AnacletoLAB/grape/blob/main/tutorials/Loading_a_Graph_in_Ensmallen.ipynb
    # under "manually load a graph"
)

g # make sure graph looks okay
# Out:
# <p>The undirected graph has 427657 nodes and 5379922 edges.</p><h3>RAM requirements</h3><p>The RAM requirements for the nodes and edges data structures are 81.83MB and 22.08MB respectively.</p><h3>Degree centrality</h3><p>The minimum node degree is 1, the maximum node degree is 99804, the mode degree is 2, the mean degree is 25.16 and the node degree median is 6.</p><p>The nodes with highest degree centrality are: TO:0000427 (degree 99804), TO:0000055 (degree 99707), TO:0000299 (degree 99457), TO:0000051 (degree 99415) and TO:0000140 (degree 98608).</p><h3>Disconnected nodes</h3><p>Disconnected nodes are nodes that are not connected to any other node.The graph contains 1 disconnected nodes.</p><h4>Singleton nodes with selfloops</h4><p>Singleton nodes with selfloops are nodes with no edge to other nodes and have exclusively selfloops. The graph contains a singleton node with selfloop, which is <a href='http://www.w3.org/2002/07/owl#Nothing' target='_blank' title='Go to OWL to get more informations about owl:Nothing'>owl:Nothing</a> (degree 1).</p>

# %%
from embiggen.pipelines import compute_node_embedding
from plot_keras_history import plot_history

node_embedding_method_name = "SkipGram"

first_order_rw_node_embedding, training_history = compute_node_embedding(
    g,
    node_embedding_method_name=node_embedding_method_name,
)

# need to use a GPU here
plot_history(
    training_history,
    title="First-order random walk based {} model applied to graph {}".format(
        node_embedding_method_name,
        g.get_name()
    )
)
# Out:
# 2021-10-22 10:14:42.108563: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_h/16xk12c16_x41bjp5j7nnj3w0000gp/T/ipykernel_51390/2454324521.py in <module>
#       4 node_embedding_method_name = "SkipGram"
#       5
# ----> 6 first_order_rw_node_embedding, training_history = compute_node_embedding(
#       7     g,
#       8     node_embedding_method_name=node_embedding_method_name,
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/embiggen/pipelines/compute_node_embedding.py in compute_node_embedding(graph, node_embedding_method_name, use_mirrored_strategy, devices, fit_kwargs, verbose, automatically_drop_unsupported_parameters, automatically_enable_time_memory_tradeoffs, automatically_sort_by_decreasing_outbound_node_degree, **kwargs)
#     337
#     338     # Call the wrapper with cache.
# --> 339     return _compute_node_embedding(
#     340         graph,
#     341         graph_name=graph.get_name(),
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/cache_decorator/cache.py in wrapped(*args, **kwargs)
#     475             # otherwise compute the result
#     476             start_time = time()
# --> 477             result = function(*args, **kwargs)
#     478             end_time = time()
#     479
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/embiggen/pipelines/compute_node_embedding.py in _compute_node_embedding(graph, graph_name, node_embedding_method_name, fit_kwargs, verbose, use_mirrored_strategy, devices, **kwargs)
#     179         with strategy.scope():
#     180             return _train_model(**kwargs)
# --> 181     return _train_model(**kwargs)
#     182
#     183
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/embiggen/pipelines/compute_node_embedding.py in _train_model(graph, node_embedding_method_name, fit_kwargs, verbose, support_mirrored_strategy, **kwargs)
#     109     )
#     110     # Fitting the node embedding model
# --> 111     history = model.fit(
#     112         verbose=verbose,
#     113         **fit_kwargs
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/embiggen/embedders/node2vec.py in fit(self, epochs, early_stopping_monitor, early_stopping_min_delta, early_stopping_patience, early_stopping_mode, reduce_lr_monitor, reduce_lr_min_delta, reduce_lr_patience, reduce_lr_mode, reduce_lr_factor, verbose, **kwargs)
#     210         Dataframe with training history.
#     211         """
# --> 212         return self._model.fit(
#     213             self._sequence,
#     214             epochs=epochs,
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/embiggen/embedders/embedder.py in fit(self, early_stopping_min_delta, early_stopping_patience, reduce_lr_min_delta, reduce_lr_patience, epochs, early_stopping_monitor, early_stopping_mode, reduce_lr_monitor, reduce_lr_mode, reduce_lr_factor, verbose, *args, **kwargs)
#     337         verbose = validate_verbose(verbose)
#     338         callbacks = kwargs.pop("callbacks", ())
# --> 339         return pd.DataFrame(self._model.fit(
#     340             *args,
#     341             epochs=epochs,
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~/Checkouts/chai/eco-kg/ecokg-embedding-gen/.venv/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
